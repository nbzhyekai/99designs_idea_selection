# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# competition_url = "https://99designs.hk/logo-design/contests/logo-design-wanted-pure-water-technology-63431"
# competition_url = "https://99designs.hk/logo-design/contests/logo-design-appointmentpost-63470"
competition_url = "https://99designs.hk/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088"

# %%
PATH = "C:\\Users\\support\\Downloads\\chromedriver_win32\\chromedriver.exe"

# %%
def make_soup(competition_url, page_number, active=True):

    kv = {'user-agent': 'Mozilla/5.0'}
    if active:
        url = competition_url + "/entries?filter=active&page=" + str(page_number)
    else: 
        url = competition_url + "/entries?filter=non_active&page=" + str(page_number)

    r = requests.get(url, headers=kv, timeout=30)
    r.raise_for_status()
    r.status_code
    r.encoding = r.apparent_encoding
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup



def get_time(soup):
    ## get time
    # text = str(soup.find(name='div', attrs='entry-pane__results').contents)
    text = str(soup.find(name='div', attrs='entry-pane__results'))
    time = re.findall('"timeCreatedString":".{20,30}"', text)
    if time:
        time = list(map(lambda x: x.replace('"timeCreatedString":"', '').replace('","', ""), time))
        return time

    time = re.findall('timeCreatedString\&quot\;\:&quot;.{20,30}\&quot\;', text)
    if time:
        time = list(map(lambda x: x[30: -6], time))
        return time

# %%
participants_user_ids = []
participants_entry_ids = []
participants_entry_image_urls = []
participants_submission_time = []

def get_participant_and_entry_info(soup):

    entry_matrix = soup.findAll(name='div', attrs='entry-matrix__item matrix__item')
    for entry in entry_matrix:
        result = entry.find(name='div', attrs='entry entry--linked entry--zoom-linked')
        try:
            participants_user_ids.append(result["data-user-id"])
            participants_entry_ids.append(result["id"])
            participants_entry_image_urls.append(result.find(name='a')["href"])
        except:
            pass

# %%
def get_ratings(competition_url, page_number, active=True):
    if active:
        url = competition_url + "/entries?filter=active&page=" + str(page_number)
    else: 
        url = competition_url + "/entries?filter=non_active&page=" + str(page_number)
    
    driver = webdriver.Chrome(PATH)
    driver.get(url)
    entry_information = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[3]/div/div/div[2]/div[5]/div[1]/div/div').get_attribute('data-design-collection')
    ratings = re.findall("\"rating\":\d|\"rating\":false", entry_information)
    ratings = list(map(lambda x: x.replace("\"rating\":", ""), ratings))
    driver.close()
    return ratings

# %%
# non deleted entries
ratings = []
page_number = 1


while True:
    # print(page_number)
    if page_number == 1:
        rating = get_ratings(competition_url, page_number)
        ratings += rating
        if len(rating) < 36:
            break
    else:

        rating = get_ratings(competition_url, page_number)
        ratings += rating
        if len(rating) < 36:
            break


    page_number += 1

# %%
page_number = 1

while True:
    if page_number == 1:
        soup = make_soup(competition_url, page_number)
        get_participant_and_entry_info(soup)
        time = get_time(soup)
        participants_submission_time += time
        if len(time) < 36:
            break
    else:
        soup = make_soup(competition_url, page_number)
        get_participant_and_entry_info(soup)
        time = get_time(soup)
        participants_submission_time += time
        if len(time) < 36:
            break

    # print(participants_user_ids)
    # print(participants_entry_ids)
    # print(participants_entry_image_urls)

    page_number += 1

# %%
entries = []
for entry_id, participant_id, time, url, rating in zip(participants_entry_ids, 
                                                participants_user_ids, 
                                                participants_submission_time, 
                                                participants_entry_image_urls,
                                                ratings):
    entries.append({'entry_id': entry_id, 'participant_id': participant_id, 'time': time, 'url':url, 'rating': rating})

# %%
entries
# Out:
# [{'entry_id': 'entry-61',
#   'participant_id': '3936695',
#   'time': '2022-10-19T08:07:44+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/61',
#   'rating': '5'},
#  {'entry_id': 'entry-35',
#   'participant_id': '2605101',
#   'time': '2022-10-18T23:45:59+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/35',
#   'rating': '5'},
#  {'entry_id': 'entry-12',
#   'participant_id': '3594446',
#   'time': '2022-10-18T09:23:22+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/12',
#   'rating': '5'},
#  {'entry_id': 'entry-40',
#   'participant_id': '2605101',
#   'time': '2022-10-19T00:20:01+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/40',
#   'rating': '4'},
#  {'entry_id': 'entry-71',
#   'participant_id': '1217383',
#   'time': '2022-10-19T13:08:59+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/71',
#   'rating': 'false'},
#  {'entry_id': 'entry-69',
#   'participant_id': '1657444',
#   'time': '2022-10-19T13:00:22+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/69',
#   'rating': 'false'},
#  {'entry_id': 'entry-68',
#   'participant_id': '1657444',
#   'time': '2022-10-19T12:59:01+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/68',
#   'rating': 'false'},
#  {'entry_id': 'entry-42',
#   'participant_id': '2605101',
#   'time': '2022-10-19T00:21:26+00:00',
#   'url': '/logo-design/contests/eye-pleasing-logo-weight-wellness-reset-program-transform-1193088/entries/42',
#   'rating': 'false'}]

# %%
def get_time_and_status_for_deleted_entry(entry_id):
    entry_id = entry_id.split('-')[-1]
    entry_url = competition_url + '/entries/' + entry_id
    
    ## make soup for entry page
    kv = {'user-agent': 'Mozilla/5.0'}
    r = requests.get(entry_url, headers=kv, timeout=30)
    r.raise_for_status()
    r.status_code
    r.encoding = r.apparent_encoding
    soup = BeautifulSoup(r.text, 'html.parser')

    ## 
    script = str(soup.find('script', id="standalone-design-details-app-data"))
    time = re.search('"timeCreatedString":".{20,30}"', script).group(0)
    time = time.replace('"timeCreatedString":"', '').replace('","', "")

    status = 'deleted'
    if re.search('"status":"withdrawn"', script):
        status = 'withdrawn'
    elif re.search('"status":"eliminated"', script):
        status = 'declined'
    

    return time, status
    


# In[33]:


def get_participant_and_entry_info_deleted_page(soup):

    user_ids = []
    entry_ids = []
    status = []
    submission_time = []
    deleted_count = 0
    withdrawn_count = 0
    declined_count = 0

    entry_matrix = soup.findAll(name='div', attrs='entry-matrix__item matrix__item')
    
    for entry in entry_matrix:
        result = entry.find(name='div', attrs='entry')
    # print(result)
        try:
            user_ids.append(result["data-user-id"])
            entry_ids.append(result["id"])
            time, s = get_time_and_status_for_deleted_entry(result["id"])
            submission_time.append(time)
            status.append(s)

            if s == 'deleted':
                deleted_count += 1
            elif s == 'withdrawn':
                withdrawn_count += 1  
            elif s == 'declined':
                declined_count += 1
                

        except:
            pass

    return user_ids, entry_ids, status, submission_time, deleted_count, withdrawn_count, declined_count


# In[34]:


deleted_participants_user_ids = []
deleted_participants_entry_ids = []
status_all = []
submission_time_all = []
total_deleted_count = 0
total_withdrawn_count = 0
total_declined_count = 0

page_number = 1

while True:
    # print(page_number)
    if page_number == 1:
        soup = make_soup(competition_url, page_number, active=False)
        user_ids, entry_ids, status, submission_time, deleted_count, withdrawn_count, declined_count = get_participant_and_entry_info_deleted_page(soup)
        deleted_participants_user_ids += user_ids
        deleted_participants_entry_ids += entry_ids
        status_all += status
        submission_time_all += submission_time
        total_deleted_count += deleted_count
        total_withdrawn_count += withdrawn_count
        total_declined_count += declined_count
        if len(user_ids) < 36:
            break
    else:
        soup = make_soup(competition_url, page_number, active=False)
        user_ids, entry_ids, status, submission_time, deleted_count, withdrawn_count, declined_count = get_participant_and_entry_info_deleted_page(soup)
        deleted_participants_user_ids += user_ids
        deleted_participants_entry_ids += entry_ids
        status_all += status
        submission_time_all += submission_time
        total_deleted_count += deleted_count
        total_withdrawn_count += withdrawn_count
        total_declined_count += declined_count
        if len(user_ids) < 36:
            break

    page_number += 1

# %%
# deleted entries
page_number = 1
deleted_ratings = []
while True:
    # print(page_number)
    if page_number == 1:
        rating = get_ratings(competition_url, page_number, False)
        deleted_ratings += rating
        if len(rating) < 36:
            break
    else:

        rating = get_ratings(competition_url, page_number, False)
        deleted_ratings += rating
        if len(rating) < 36:
            break


    page_number += 1

# %%
deleted_entries = []
for entry_id, participant_id, status, submission_time, rating in zip(deleted_participants_entry_ids, 
                                    deleted_participants_user_ids, status_all, submission_time_all, deleted_ratings):
    deleted_entries.append({'entry_id': entry_id, 'participant_id': participant_id, 'status': status, 'time': submission_time, 'rating': rating})

# %%
len(deleted_entries)
# Out:
# 63

# %%
entries
# Out:
# []

# %%
deleted_entries
# Out:
# [{'entry_id': 'entry-43',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-19T00:21:50+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-37',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-19T00:04:20+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-36',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T23:47:11+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-13',
#   'participant_id': '3594446',
#   'status': 'withdrawn',
#   'time': '2022-10-18T09:35:25+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-4',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-18T07:06:39+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-2',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-18T06:45:41+00:00',
#   'rating': '5'},
#  {'entry_id': 'entry-49',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T02:00:17+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-45',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T01:40:13+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-38',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-19T00:04:59+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-26',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T20:00:17+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-8',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-18T08:40:05+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-7',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-18T08:16:05+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-5',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T07:08:38+00:00',
#   'rating': '4'},
#  {'entry_id': 'entry-19',
#   'participant_id': '3131179',
#   'status': 'withdrawn',
#   'time': '2022-10-18T13:39:56+00:00',
#   'rating': '3'},
#  {'entry_id': 'entry-18',
#   'participant_id': '2986244',
#   'status': 'declined',
#   'time': '2022-10-18T13:10:58+00:00',
#   'rating': '3'},
#  {'entry_id': 'entry-70',
#   'participant_id': '1217383',
#   'status': 'withdrawn',
#   'time': '2022-10-19T13:06:02+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-67',
#   'participant_id': '263512',
#   'status': 'withdrawn',
#   'time': '2022-10-19T11:52:10+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-66',
#   'participant_id': '263512',
#   'status': 'withdrawn',
#   'time': '2022-10-19T11:42:45+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-65',
#   'participant_id': '2685726',
#   'status': 'declined',
#   'time': '2022-10-19T11:40:07+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-64',
#   'participant_id': '263512',
#   'status': 'withdrawn',
#   'time': '2022-10-19T11:35:51+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-63',
#   'participant_id': '1851001',
#   'status': 'withdrawn',
#   'time': '2022-10-19T09:08:22+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-62',
#   'participant_id': '1830842',
#   'status': 'withdrawn',
#   'time': '2022-10-19T08:22:20+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-60',
#   'participant_id': '2254652',
#   'status': 'declined',
#   'time': '2022-10-19T06:08:52+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-59',
#   'participant_id': '1207811',
#   'status': 'declined',
#   'time': '2022-10-19T04:40:19+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-58',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T03:54:37+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-57',
#   'participant_id': '5108468',
#   'status': 'withdrawn',
#   'time': '2022-10-19T03:45:43+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-56',
#   'participant_id': '633622',
#   'status': 'declined',
#   'time': '2022-10-19T03:29:30+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-55',
#   'participant_id': '633622',
#   'status': 'declined',
#   'time': '2022-10-19T03:22:06+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-54',
#   'participant_id': '633622',
#   'status': 'declined',
#   'time': '2022-10-19T03:21:42+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-53',
#   'participant_id': '4581623',
#   'status': 'withdrawn',
#   'time': '2022-10-19T03:02:17+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-52',
#   'participant_id': '3594446',
#   'status': 'withdrawn',
#   'time': '2022-10-19T02:56:52+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-51',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T02:06:18+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-50',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T02:01:51+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-48',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T01:53:14+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-47',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T01:48:08+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-46',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-19T01:42:27+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-44',
#   'participant_id': '3594446',
#   'status': 'withdrawn',
#   'time': '2022-10-19T01:34:10+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-41',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-19T00:20:28+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-39',
#   'participant_id': '1230911',
#   'status': 'withdrawn',
#   'time': '2022-10-19T00:05:25+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-34',
#   'participant_id': '2218606',
#   'status': 'declined',
#   'time': '2022-10-18T23:30:03+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-33',
#   'participant_id': '3905855',
#   'status': 'withdrawn',
#   'time': '2022-10-18T23:21:44+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-32',
#   'participant_id': '3905855',
#   'status': 'withdrawn',
#   'time': '2022-10-18T23:11:24+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-31',
#   'participant_id': '3905855',
#   'status': 'withdrawn',
#   'time': '2022-10-18T23:07:44+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-30',
#   'participant_id': '3905855',
#   'status': 'withdrawn',
#   'time': '2022-10-18T23:07:01+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-29',
#   'participant_id': '3905855',
#   'status': 'withdrawn',
#   'time': '2022-10-18T23:03:00+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-28',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T20:02:38+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-27',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T20:02:19+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-25',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T19:59:55+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-24',
#   'participant_id': '2196023',
#   'status': 'declined',
#   'time': '2022-10-18T17:10:20+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-23',
#   'participant_id': '774933',
#   'status': 'declined',
#   'time': '2022-10-18T16:36:58+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-22',
#   'participant_id': '2869264',
#   'status': 'withdrawn',
#   'time': '2022-10-18T16:00:22+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-21',
#   'participant_id': '3936695',
#   'status': 'withdrawn',
#   'time': '2022-10-18T15:24:15+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-20',
#   'participant_id': '3296327',
#   'status': 'declined',
#   'time': '2022-10-18T14:08:17+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-17',
#   'participant_id': '3929605',
#   'status': 'declined',
#   'time': '2022-10-18T12:46:18+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-16',
#   'participant_id': '3929605',
#   'status': 'declined',
#   'time': '2022-10-18T12:39:11+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-15',
#   'participant_id': '2562897',
#   'status': 'declined',
#   'time': '2022-10-18T12:23:39+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-14',
#   'participant_id': '1230911',
#   'status': 'withdrawn',
#   'time': '2022-10-18T10:47:12+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-11',
#   'participant_id': '2075592',
#   'status': 'withdrawn',
#   'time': '2022-10-18T09:14:09+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-10',
#   'participant_id': '3594446',
#   'status': 'withdrawn',
#   'time': '2022-10-18T09:03:24+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-9',
#   'participant_id': '2075592',
#   'status': 'withdrawn',
#   'time': '2022-10-18T08:51:48+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-6',
#   'participant_id': '543771',
#   'status': 'declined',
#   'time': '2022-10-18T07:41:25+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-3',
#   'participant_id': '2196321',
#   'status': 'withdrawn',
#   'time': '2022-10-18T06:56:30+00:00',
#   'rating': 'false'},
#  {'entry_id': 'entry-1',
#   'participant_id': '2605101',
#   'status': 'declined',
#   'time': '2022-10-18T05:25:45+00:00',
#   'rating': 'false'}]
